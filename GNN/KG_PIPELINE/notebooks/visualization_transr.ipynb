# %% [markdown]
# # Download FreeBase mid dictionary

# %%
import sys
sys.path.insert(0,'..')

from pandas import read_csv

from google_drive_downloader import GoogleDriveDownloader as gdd
# gdd.download_file_from_google_drive(file_id='0B52yRXcdpG6MaHA5ZW9CZ21MbVk',
#                                     dest_path='../data/mid2entity.tsv.gz')

mid2name = read_csv('../raw_data/mid2entity.tsv.gz',sep='\t',compression='gzip', names=['mid','entity'])
mid2ent = {i:e for i,e in zip(mid2name['mid'],mid2name['entity'])}
mid2ent
# Out:
# {'/m/0gw0': 'Anarcism',
#  '/m/0gwj': 'Autisim',
#  '/m/0gx0': 'Albedo rate',
#  '/m/0gxj': 'Abû Zabi',
#  '/m/0gy0': 'A.',
#  '/m/0gyh': 'Alabama (state)',
#  '/m/0gy_': 'Achillies',
#  '/m/0gzh': 'President Abraham',
#  '/m/0gz_': 'The Stagirite',
#  '/m/0g_h': 'AnAmericanInParis',
#  '/m/0g_w': 'The Oscars',
#  '/m/0h0c': 'Animalia (book)',
#  '/m/0h0q': 'Atomic time',
#  '/m/0h16': 'Altruistically',
#  '/m/0h1p': '李安',
#  '/m/0h25': 'Ayb rand',
#  '/m/0h2p': 'Allan Connes',
#  '/m/0h34': 'Allen Dwan',
#  '/m/0h3y': "Ad-Dimuqratiyah ash-Sha'biyah",
#  '/m/0h53': 'Ayn Rand Atlas Shrugged',
#  '/m/0h5k': 'Historical anthropologist',
#  '/m/0h61': 'Archeology',
#  '/m/0h6k': 'The Agricultural Sciences',
#  '/m/0h70': 'Alchemist',
#  '/m/0h7j': 'Automatic dependent surveillance broadcast',
#  '/m/0h7x': 'Austrian Republic',
#  '/m/0h8d': 'America Samoa',
#  '/m/0h9c': 'Astronom',
#  '/m/0h9v': 'Theratromyxa',
#  '/m/0hb8': 'Bemer-Ross Code',
#  '/m/0hcr': 'Animated images',
#  '/m/0hd7': 'Phanaeus',
#  '/m/0hdr': 'Andre Kirk Agassi',
#  '/m/0hf7': 'Mon-Khmer Languages',
#  '/m/0hfp': 'Afro-Asiatic peoples',
#  '/m/0hg5': 'Principality of Andorra',
#  '/m/0hgp': 'Sample means',
#  '/m/0hh4': 'American football conference',
#  '/m/0hhy': 'Animal Farm (novel)',
#  '/m/0hjf': 'Amphibion',
#  '/m/0hjy': 'Town (Alaska)',
#  '/m/0hkf': 'Agricultural methods',
#  '/m/0hky': 'Aldous Leonard Huxley',
#  '/m/0hlw': 'Alge',
#  '/m/0hmc': 'Variance analysis',
#  '/m/0hmw': 'Heptapentacontane',
#  '/m/0hnc': 'Notice of Appeal',
#  '/m/0hnv': 'Answer (law)',
#  '/m/0hp6': 'Arraignments',
#  '/m/0hpk': 'Sea to shining sea',
#  '/m/0hpx': 'Adaptive technology',
#  '/m/0hq8': 'AbacuS',
#  '/m/0hqs': 'Polyprotic',
#  '/m/0hr8': 'Stamped asphalt',
#  '/m/0hrr': 'USASI',
#  '/m/0hsp': 'Evoloterra',
#  '/m/0ht5': 'Apollo8',
#  '/m/0htp': 'Taikanaut',
#  '/m/0hv5': 'A modest proposal',
#  '/m/0hvl': 'Lithium family',
#  '/m/0hwf': "Abc's",
#  '/m/0hwy': 'Proton number',
#  '/m/0hxf': 'Anatomically',
#  '/m/0hxy': 'Commutation of conditionals',
#  '/m/0hy8': 'Andrei Arsenyevich Tarkovsky',
#  '/m/0hz5': 'Aardvaark',
#  '/m/0hzp': 'Proteles cristata',
#  '/m/0h_4': 'Adobe brick',
#  '/m/0h_m': 'Adventurers',
#  '/m/0j01': 'Agave (botany)',
#  '/m/0j0k': 'Yazhou',
#  '/m/0j11': 'ISO 3166-1:AW',
#  '/m/0j1k': 'The Articles of Confederation',
#  '/m/0j2v': 'Kosztler Artur',
#  '/m/0j3b': 'Northern Atlantic',
#  '/m/0j3v': 'Schopenhauer, A.',
#  '/m/0j4b': 'ISO 3166-1:AO',
#  '/m/0j7s': 'Albert Sydney Johnston',
#  '/m/0j85': 'East Greenland Rift Basins',
#  '/m/0j8p': 'Artificial Person',
#  '/m/0j95': 'Laughlin City',
#  '/m/0j9p': 'Artic Circle',
#  '/m/0jb3': 'Assult rifle',
#  '/m/0jbk': 'Kingdom Animalia',
#  '/m/0jc1': 'Astronomy & Astrophysics Supplement',
#  '/m/0jcd': 'Chondrostean',
#  '/m/0jcx': 'Einstien',
#  '/m/0jdd': 'Afgahanistan',
#  '/m/0jdx': 'Republic of Albania',
#  '/m/0jfd': 'Ollah',
#  '/m/0jfx': '85th parallel south',
#  '/m/0jgd': 'Arxentina',
#  '/m/0jgx': 'Armenie',
#  '/m/0jhd': 'Azerbaydzhan',
#  '/m/0jhx': 'Star gazing',
#  '/m/0jjc': 'Aikidō',
#  '/m/0jjw': 'Public art studies',
#  '/m/0jkw': 'Agnostid',
#  '/m/0jl9': 'Physical Effects of Abortion',
#  '/m/0jlt': 'Abstract of the disclosure',
#  '/m/0jmj': 'Alda, Alan',
#  '/m/0jm_': 'American Football',
#  '/m/0jnh': 'Revolutionary war',
#  '/m/0jn_': 'Exa-ampere',
#  '/m/0jpv': 'Continuous algorithm',
#  '/m/0jqb': 'Winter annual',
#  '/m/0jqr': 'Anthophytes',
#  '/m/0jr2': 'Antiseptic mouth rinse',
#  '/m/0jrg': 'Alexander the graet',
#  '/m/0jrz': 'Habdank',
#  '/m/0jsd': 'Asteroids Hyper 64',
#  '/m/0jsv': 'Asparagales',
#  '/m/0jt9': 'Alismatanae',
#  '/m/0jts': 'Apiales',
#  '/m/0jv7': 'Asterales',
#  '/m/0jvq': '(50001) 2000 AK15',
#  '/m/0jw6': 'Allocute',
#  '/m/0jwk': 'Affiant',
#  '/m/0jwy': '♈ (constellation)',
#  '/m/0jxf': 'Water bearer',
#  '/m/0jxy': 'Japanimation',
#  '/m/0jyw': 'Enguru',
#  '/m/0jzc': 'History of the Arabic language',
#  '/m/0jzw': 'Chief Phillips',
#  '/m/0j_c': 'Alfred J. Hitchcock',
#  '/m/0j_w': 'Andaconda',
#  '/m/0k0c': 'AllSaints',
#  '/m/0k0w': 'Altaic',
#  '/m/0k1b': 'Austrian Standard German',
#  '/m/0k1r': 'ZF¬C',
#  '/m/0k26': 'Avitokhol',
#  '/m/0k2q': 'Agean Sea',
#  '/m/0k36': 'A Clockwork Orange (book)',
#  '/m/0k3p': 'Amsterdam, The Netherlands',
#  '/m/0k45': 'Arbetets museum',
#  '/m/0k4j': 'Motorization',
#  '/m/0k50': 'Audi Aktien-Gesellschaft',
#  '/m/0k5j': 'Aircafts',
#  '/m/0k60': 'Soit P.P.',
#  '/m/0k6j': "Alfred Nobel's",
#  '/m/0k70': 'The father of the deaf',
#  '/m/0k7j': 'Amhran na bhfiann',
#  '/m/0k80': 'Geography of Anatolia',
#  '/m/0k8z': 'Apple (computer)',
#  '/m/0k9g': 'Ythsie',
#  '/m/0kb6': 'AnschluB',
#  '/m/0kbq': 'Secession, War of',
#  '/m/0kc6': 'Andrew Warhol',
#  '/m/0kdl': 'Alp-Arslan',
#  '/m/0kf0': 'AFI Fest',
#  '/m/0kfg': 'Author theory',
#  '/m/0kft': 'Akira kurosawa',
#  '/m/0kg9': 'Pharonic',
#  '/m/0kgs': 'The Analog Brothers',
#  '/m/0kh3': 'Primary muscular atrophy',
#  '/m/0khl': 'Impure abjad',
#  '/m/0kj0': 'Pseudo-alphabet',
#  '/m/0kjh': 'ABBA in the United States',
#  '/m/0kj_': 'Alegiance',
#  '/m/0kkd': 'Majority of the fixed membership',
#  '/m/0kl4': 'Adventure International',
#  '/m/0klw': 'Ac clarke',
#  '/m/0kmc': 'Apple MessagePad',
#  '/m/0kmw': 'AE van Vogt',
#  '/m/0knc': 'April fools RFC',
#  '/m/0knq': 'Kurnikova',
#  '/m/0kp5': 'Alfons Maria Jakob',
#  '/m/0kpl': 'Atheistic',
#  '/m/0kq2': 'Unknowably',
#  '/m/0ktl': 'Atomic chemical',
#  '/m/0kv2': 'Arable agriculture',
#  '/m/0kw9': 'Abdicator',
#  '/m/0kwr': 'Anglican Communion/1911',
#  '/m/0kx6': 'Arne Kaijser',
#  '/m/0kxk': 'Archepolego',
#  '/m/0ky1': 'Sir Arthur Doyle',
#  '/m/0kyk': 'Authour',
#  '/m/0kz0': 'Markov Andrei',
#  '/m/0kzh': 'Alumnus/a',
#  '/m/0kzw': 'Existential dread',
#  '/m/0k_9': 'Anxiogenesis',
#  '/m/0k_s': 'AA Milne',
#  '/m/0l08': 'Oholic',
#  '/m/0l0r': 'Postulates',
#  '/m/0l17': 'Α (letter)',
#  '/m/0l1r': 'Heidi Toffler',
#  '/m/0l27': 'The Amazing SpiderMan',
#  '/m/0l3h': 'North Sound',
#  '/m/0l3_': 'A Man for All Seasons, film',
#  '/m/0l4c': 'Azincourt',
#  '/m/0l4t': 'Berthold Konrad Hermann Albert Speer',
#  '/m/0l5r': 'Composite plant',
#  '/m/0l67': 'Umbellifer',
#  '/m/0l6q': 'Nerve fibre',
#  '/m/0l76': 'Aramaean alphabet',
#  '/m/0l80': 'AsWeMayThink',
#  '/m/0l8d': 'American shot',
#  '/m/0l8t': 'Acute Disseminated Encephalomyelitis',
#  '/m/0l95': 'Loss of coordination',
#  '/m/0l9n': 'Alhazred',
#  '/m/0lb2': 'Ada Byron',
#  '/m/0lbl': 'AmbientCalculiOnline',
#  '/m/0lby': 'August derleth bibliography',
#  '/m/0lcd': 'Alpine nations',
#  '/m/0lcx': 'Absurd hero',
#  '/m/0ldd': 'Dame Agatha Christie',
#  '/m/0ldx': 'Albert Camus/The Plague',
#  '/m/0lfc': 'AppliedEthics',
#  '/m/0lft': 'Ricardo Clement',
#  '/m/0lg9': 'Absolute Square',
#  '/m/0lgt': 'Arches National Monument',
#  '/m/0lh7': 'Analog data',
#  '/m/0lj5': 'And Then There Were None...',
#  '/m/0ljm': 'Poirot',
#  '/m/0lk3': 'Ms Marple',
#  '/m/0lkm': 'Apr.',
#  '/m/0ll3': 'Auggust',
#  '/m/0llm': 'Haaroon',
#  '/m/0lm1': 'Apr 4',
#  '/m/0lmk': 'April 06',
#  '/m/0ln1': '12 April',
#  '/m/0lnk': 'April 15, 2011',
#  '/m/0lp1': '30th April',
#  '/m/0lpk': '22nd August',
#  '/m/0lq1': 'Historical anniversaries/August 27',
#  '/m/0lqk': 'Non-beverage alcohol',
#  '/m/0lr1': 'Oileán Acla',
#  '/m/0lrh': 'Allan Ginsberg',
#  '/m/0lr_': 'Algebraically closed',
#  '/m/0lsg': 'August 6th',
#  '/m/0lsz': 'Anatoli Karpow',
#  '/m/0ltv': 'Racing cars',
#  '/m/0lvb': 'Capitalist anarchy',
#  '/m/0lvv': '9 August',
#  '/m/0lwb': 'Aristophanic',
#  '/m/0lxb': 'Austrian economists',
#  '/m/0lxt': 'Phagadenic abscess',
#  '/m/0ly9': 'Abwer',
#  '/m/0lyq': 'Ancestral Pueblo',
#  '/m/0lz5': 'Aalborg Municipality',
#  '/m/0lzp': 'Engineering College of Aarhus',
#  '/m/0l_5': 'Northern Cavefish',
#  '/m/0l_j': 'Abandonment of domicile',
#  '/m/0m09': 'Top-fermented beer',
#  '/m/0m0s': 'Amature',
#  '/m/0m17': 'Ambrose Gwinett Bierce',
#  '/m/0m1r': 'Alexis Carrell',
#  '/m/0m27': 'Robert Anthony Eden',
#  '/m/0m2r': "All-Souls' Day",
#  '/m/0m34': 'Jacques Anatole Francois Thibault',
#  '/m/0m3n': 'A. Gide',
#  '/m/0m4h': 'Variance/Algorithm',
#  '/m/0m4v': 'Almond Bitter Oil',
#  '/m/0m61': 'Roots of anti-Semitism',
#  '/m/0m8m': '13th August',
#  '/m/0m93': 'Abitianus',
#  '/m/0m9m': 'The ashes',
#  '/m/0mb0': "Anne O'Brien",
#  '/m/0mbz': 'Abner Doubleday',
#  '/m/0mcc': 'Americas National Game',
#  '/m/0mcq': 'Amplitude Based',
#  '/m/0md6': 'Augustin Jean Fresnel',
#  '/m/0mdn': 'Abbéville',
#  '/m/0mf2': 'Abbot-General',
#  '/m/0mfl': 'A. r. ramidus',
#  '/m/0mfz': 'Assembly process',
#  '/m/0mgp': 'Athens of the South',
#  '/m/0mh5': 'Alan Garner',
#  '/m/0mhl': 'August 2nd',
#  '/m/0mj2': 'Algebraics',
#  '/m/0mjl': 'Tolliver Groat',
#  '/m/0mj_': 'Automorphisms',
#  '/m/0mkg': 'Accordeon',
#  '/m/0mkz': 'Computer AI',
#  '/m/0mlv': 'Classical philosophy',
#  '/m/0mm8': 'Anaxamander',
#  '/m/0mn6': 'The Architect',
#  '/m/0mnq': 'Abbr',
#  '/m/0mp6': 'AbstractAlgebra',
#  '/m/0mpp': 'Kythereia',
#  '/m/0mq5': '1st of April',
#  '/m/0mqp': 'Anti-symmetric relation',
#  '/m/0mr2': 'Alistair Crowley',
#  '/m/0mrl': 'After-death',
#  '/m/0ms1': 'Astrometrics',
#  '/m/0msj': 'Pallas Athena (goddess)',
#  '/m/0mt0': 'Amber diceless rpg',
#  '/m/0mtf': 'Alloyed',
#  '/m/0mty': 'Article of faith',
#  '/m/0mvp': 'Artistic revolution',
#  '/m/0mw0': 'Ruralism',
#  '/m/0mwc': 'Reflex angle',
#  '/m/0mx6': 'Acoustical',
#  '/m/0mxq': 'Atom physics',
#  '/m/0my5': 'ISO 639:ase',
#  '/m/0myl': 'Applets',
#  '/m/0mz2': 'Alternate timeline',
#  '/m/0mzl': 'Audiogalaxy Satellite',
#  '/m/0m_0': 'Empty orbital',
#  '/m/0m_j': 'D-amino acids',
#  '/m/0n00': 'A. Turing',
#  '/m/0n0j': 'Area of plane region',
#  '/m/0n0_': 'Astronomical units',
#  '/m/0n1h': 'Artists',
#  '/m/0n1z': 'Aktaion',
#  '/m/0n2g': 'Anglican divine',
#  '/m/0n2z': 'Atina, Greece',
#  '/m/0n3g': 'Anguilla/Transnational issues',
#  '/m/0n3z': 'Cartier Island Marine Reserve',
#  '/m/0n4g': 'Acoustic theory',
#  '/m/0n4t': 'Mackenzie, Alexander',
#  '/m/0n56': 'Treaty of annexation',
#  '/m/0n5l': 'Aśokaḥ',
#  '/m/0n6y': 'Ada programming',
#  '/m/0n7f': 'Alfonso Arau',
#  '/m/0n7v': 'Alfonso Cuaron',
#  '/m/0n8b': 'Meighen',
#  '/m/0n8r': 'Arianian',
#  '/m/0n97': '1st of August',
#  '/m/0n9r': 'Antonino Pio',
#  '/m/0nb7': 'Severan Wall',
#  '/m/0nbq': 'August 3rd',
#  '/m/0nc6': 'Aes128',
#  '/m/0ncq': 'April 26th',
#  '/m/0nd6': 'French slang',
#  '/m/0ndq': 'Anisotropic',
#  '/m/0nf5': 'Alpha emission',
#  '/m/0nfn': 'Abject poverty',
#  '/m/0nf_': 'Analytical Engine/redirects',
#  '/m/0ngg': 'Octavianus Augustus',
#  '/m/0nk1': 'Apocryphal literature',
#  '/m/0nkk': 'Augusti',
#  '/m/0nky': 'Antarctica Treaty',
#  '/m/0nld': 'Algernon Swinburne',
#  '/m/0nlv': 'Alfred William Lawson',
#  '/m/0nmj': 'Iowa Ames',
#  '/m/0nmx': 'Nordotis',
#  '/m/0nnc': 'Äbtissin',
#  '/m/0np6': 'AbdominalSurgery',
#  '/m/0npz': 'AbensbergGermany',
#  '/m/0nqc': 'Arminians',
#  '/m/0nqv': 'Alan Parsons Project (band)',
#  '/m/0nr8': 'Frivolous Theorem of Arithmetic',
#  '/m/0nsc': 'Monocyclic aromatic hydrocarbon',
#  '/m/0nsv': 'AbbeY',
#  '/m/0nt9': 'Annale School of History',
#  '/m/0ntt': 'Anti Universe',
#  '/m/0nv9': 'Casa Battlo',
#  '/m/0nvs': 'Parc Güell',
#  '/m/0nw8': 'La Pedera',
#  '/m/0nws': 'Feynman–Stueckelberg interpretation',
#  '/m/0nxm': 'August 7th',
#  '/m/0ny3': '08 August',
#  '/m/0nym': 'April 16, 2008',
#  '/m/0nz3': 'Associative property',
#  '/m/0nzm': 'Apache software foundation',
#  '/m/0n_3': 'The Americans with Disabilites Act of 1990/Findings and Purposes',
#  '/m/0n_h': 'Active recall',
#  '/m/0n_v': 'Apple 1',
#  '/m/0p0b': 'Apatosaurus ajax',
#  '/m/0p0v': 'MOR 693',
#  '/m/0p1b': 'Kalashnikopies',
#  '/m/0p1v': 'ABC Computer',
#  '/m/0p29': 'Association of C and C Plus Plus Users',
#  '/m/0p2n': 'Andean Mountain System',
#  '/m/0p34': 'Ancylopoda',
#  '/m/0p3h': 'Engraulis encrasicholus',
#  '/m/0p3x': 'Maritime anchor',
#  '/m/0p4c': 'Firuz-shabur',
#  '/m/0p4q': 'Anavarza',
#  '/m/0p53': 'Anagrammatic',
#  '/m/0p5m': 'Anadyr River',
#  '/m/0p5_': 'André Marie Ampére',
#  '/m/0p6h': 'Amoeba (Cell)',
#  '/m/0p6_': 'Nitro-sil',
#  '/m/0p7h': 'Amithist',
#  '/m/0p7z': 'Albertasaurus',
#  '/m/0p8g': 'Assembler language',
#  '/m/0p8z': 'Food of the gods (mythology)',
#  '/m/0p9f': 'St Ambrosius',
#  '/m/0p9y': 'Ampracia',
#  '/m/0pbc': 'Roumanite',
#  '/m/0pbw': 'Amalaric',
#  '/m/0pc9': 'Alpine horn',
#  '/m/0pcr': 'Lama pacos',
#  '/m/0pd7': 'Land force',
#  '/m/0pf2': 'History of applied mathematics',
#  '/m/0pfk': 'Alligatorid',
#  '/m/0pg0': 'Aleutian Islands (Alaska)',
#  '/m/0pgj': 'Sialidae',
#  '/m/0pgw': 'Alders',
#  '/m/0phc': 'Alcott family',
#  '/m/0phs': 'Arachnophobe',
#  '/m/0pj6': 'Alabastar',
#  '/m/0pjp': 'Ehav',
#  '/m/0pkg': 'Agoutinae',
#  '/m/0pkx': 'Beta Persei',
#  '/m/0pld': 'Amazing Grace lyrics',
#  '/m/0plw': 'AOLer',
#  '/m/0pmb': 'Algebra 1',
#  '/m/0pmv': 'BC vs AD',
#  '/m/0pp4': 'Alcuin Of York',
#  '/m/0ppm': 'Angilbert, Saint',
#  '/m/0pq0': 'Tert-Amine',
#  '/m/0pqh': 'April 29th',
#  '/m/0pq_': '14 August',
#  '/m/0prh': 'Absolute Zero',
#  '/m/0pr_': 'Adiabatic transformation',
#  '/m/0psh': 'Amides',
#  '/m/0ps_': 'Animsim',
#  '/m/0pth': 'Vivaldi',
#  '/m/0pvf': 'Aareschlucht Innertkirchen-Meiringen',
#  '/m/0pvy': 'Clartyhole',
#  '/m/0pwb': 'Avram',
#  '/m/0pwv': 'Abraxias',
#  '/m/0pxb': 'Abshaluom',
#  '/m/0py5': 'Great Temple of Abydos',
#  '/m/0pyn': 'Hellespont Abydos',
#  '/m/0pz0': '15th of August',
#  '/m/0pzy': 'Acasia',
#  '/m/0p_f': 'Acapulco de Juárez',
#  '/m/0p_x': 'Adriatic Coast',
#  '/m/0q0d': '16 aug',
#  '/m/0q0x': 'Alan Curtis Kay',
#  '/m/0q1d': 'APL\\\\360',
#  '/m/0q1x': 'Algol programming language',
#  '/m/0q2c': 'Awk (language)',
#  '/m/0q2w': 'Augustus de Morgan',
#  '/m/0q3c': 'Asguard',
#  '/m/0q3w': 'Command Module Pilot',
#  '/m/0q4c': 'Drubbing',
#  '/m/0q4r': 'Elphame',
#  '/m/0q55': 'Askr',
#  '/m/0q5n': 'Alabama River (United States)',
#  '/m/0q60': 'Alanus ab Insulis',
#  '/m/0q6g': 'Alemans',
#  '/m/0q6y': 'NYSE Amex',
#  '/m/0q7d': 'Aug 17',
#  '/m/0q7x': 'August 12th',
#  '/m/0q8r': 'Alfred Wallace',
#  '/m/0q96': 'ALP (Australia)',
#  '/m/0q9p': 'August 18th',
#  '/m/0qb5': 'Aug 19',
#  '/m/0qbp': '20 August',
#  '/m/0qc5': 'Aug 21',
#  '/m/0qcp': 'Alices Adventures in Wonderland/Dodo',
#  '/m/0qdc': 'Alices Adventures in Wonderland/The Eaglet',
#  '/m/0qg9': 'Albert The Warlike',
#  '/m/0qgp': 'Albrecht von Ballenstein',
#  '/m/0qh3': 'Albrecht of Mainz',
#  '/m/0qhh': 'Albert of Prussia',
#  '/m/0qhx': 'Aug 25',
#  '/m/0qjd': 'Free City of Aachen',
#  '/m/0qjx': 'Mocha Stone',
#  '/m/0qkc': 'Acetylsalicylic Acid',
#  '/m/0qkw': 'Avner',
#  '/m/0ql7': 'Sultan Ahmed I',
#  '/m/0qlr': 'Achmet II',
#  '/m/0qm7': 'Achmet III',
#  '/m/0qmq': 'Utari',
#  '/m/0qn6': 'Akropoli, Athens',
#  '/m/0qnq': 'Acupuncture in medicine',
#  '/m/0qpk': 'Æneas',
#  '/m/0qq1': 'Apr 13',
#  '/m/0qqk': 'Amaranthus',
#  '/m/0qr0': 'Agapanthus umbellatus',
#  '/m/0qrc': 'Agamémnon',
#  '/m/0qrw': 'Hasan Ali Shah',
#  '/m/0qs6': 'Mahomed Shah Aga Khan',
#  '/m/0qsn': 'Agasias of Ephesus',
#  '/m/0qt1': 'Alexander Agassiz',
#  '/m/0qtf': 'Ἀγάθων',
#  '/m/0qtv': 'Agesilaus',
#  '/m/0qvm': 'Antonio Cardinal Agliardi',
#  '/m/0qw0': 'Agnes of Meran',
#  '/m/0qwf': 'Agneyastra',
#  '/m/0qwy': 'Agrippina maior',
#  '/m/0qxd': 'Agrippina Minor',
#  '/m/0qxx': 'Chinese take away',
#  '/m/0qym': 'St. Aidan',
#  '/m/0qz0': 'Arthur Aikin',
#  '/m/0qzd': 'Ailanthus',
#  '/m/0qzw': 'Adrevald of Fleury-sur-Loire',
#  '/m/0q_7': 'Arrival of the Semites to Babylonia and Assyria',
#  '/m/0q_q': 'Locrian Ajax',
#  '/m/0r06': 'Telemonian Ajax',
#  '/m/0r16': 'Alaric, King of the Visigoths',
#  '/m/0r1p': 'Alarik II',
#  '/m/0r24': 'Albert von Bollstädt',
#  '/m/0r2n': 'Alouion',
#  '/m/0r33': 'Albuin',
#  '/m/0r3k': 'Afonzo de Albuquerque',
#  '/m/0r3_': 'Alcaeus of Mitylene',
#  '/m/0r4g': 'Alkamenes',
#  '/m/0r4v': 'Alcmena',
#  '/m/0r59': 'Alcidamas of Elaea',
#  '/m/0r5p': 'Aldine Editions',
#  '/m/0r61': 'Aldred',
#  '/m/0r6d': 'Alexander i of epirus',
#  '/m/0r6v': 'Αλέξανδρος Bάλας',
#  '/m/0r77': 'Alexander of pherae',
#  '/m/0r7n': 'Alexander ii of epirus',
#  '/m/0r80': 'Aleksandras, Grand Duke of Lithuania',
#  '/m/0r8f': 'Alieksandr I Pavlovich',
#  '/m/0r8y': 'Russian Tsar Alexander II',
#  '/m/0r9f': 'Aleksandr III Aleksandrovich',
#  '/m/0r9y': 'Alaxandair I of Scotland',
#  '/m/0rbc': 'Joan of England, Queen Alexander',
#  '/m/0rbt': 'Aleksandar Obrenovic',
#  '/m/0rc6': 'Alexander iii of scotland',
#  '/m/0rc_': 'Alexander of aphrodisias',
#  '/m/0rdc': 'Alejandro Severo',
#  '/m/0rgp': 'Alexander of aetolia',
#  '/m/0rh0': 'Alexander Jannnaeus',
#  '/m/0rhx': 'Alexandrist',
#  '/m/0rj7': 'Emperor Alexios I',
#  '/m/0rjr': 'Alexis',
#  '/m/0rk3': 'Alexius II Comnenus',
#  '/m/0rkm': 'Emperor Alexios III',
#  '/m/0rl2': 'Murzuphlus',
#  '/m/0rlk': 'Tsarevich Alexei',
#  '/m/0rlz': 'President Andrew Jackson’s',
#  '/m/0rmg': 'A. Johnson Administration',
#  '/m/0rmz': 'Alexander Solzhynitsyn',
#  '/m/0rng': 'Aberdeen City Police',
#  '/m/0rnz': 'August 23rd',
#  '/m/0rpg': 'Aug 24',
#  '/m/0rpz': 'Anti-Pope',
#  '/m/0rqg': 'Aquafarming',
#  '/m/0rqy': 'Kolmogorov-Chaitin complexity',
#  '/m/0rrb': 'Algernon Swinburne/Hymn to Proserpine',
#  '/m/0rrp': 'Algernon Swinburne/The Triumph of Time',
#  '/m/0rs0': 'Famous 28 April Born personalities',
#  '/m/0rsj': 'Aelfred',
#  '/m/0rt0': 'Algardi',
#  '/m/0rth': 'Alger of Liége',
#  '/m/0rtv': 'El Djazair',
#  '/m/0rvb': 'Critique of Ptolemy',
#  '/m/0rvt': 'Alessandro Allori',
#  '/m/0rw8': 'Murabitids',
#  '/m/0rws': 'Aloe plant',
#  '/m/0rx8': 'Alyattes II',
#  '/m/0rxp': 'Close-in age',
#  '/m/0ry4': 'Alypius of antioch',
#  '/m/0ryh': 'Amalswinthe',
#  '/m/0ryy': 'Amauri de Bène',
#  '/m/0rzb': 'Alfonso I of Portugal',
#  '/m/0rzv': 'Afonso el Grosso',
#  '/m/0r_9': 'Alphonse III of Portugal',
#  '/m/0r_s': 'Affonso IV',
#  '/m/0s07': 'Afonso V',
#  '/m/0s0q': 'Afonso VI',
#  '/m/0s1k': 'Alphonse II of Asturias',
#  '/m/0s20': 'Amarasimha',
#  '/m/0s2c': 'Alfonso XII, King of Spain',
#  '/m/0s2v': 'Alfonso XIII',
#  '/m/0s3b': 'Alphonso de Cartagena',
#  '/m/0s3p': 'Alfonso I of Aragón',
#  '/m/0s43': 'Amaryllis belladonna',
#  '/m/0s4g': 'Alfonso III of Aragón',
#  '/m/0s4y': 'Alfonso IV of Aragón',
#  '/m/0s5d': 'Ahmose II',
#  '/m/0s5w': 'Alphonse V of Aragon',
#  '/m/0s6b': 'Amathous',
#  '/m/0s7l': 'Amatis',
#  '/m/0s9q': 'Prothoe (Amazon)',
#  '/m/0sbl': 'Ambre gris',
#  '/m/0sc1': 'Ambiorix',
#  '/m/0scw': 'A. W. Ambros',
#  '/m/0sd7': 'Amazon River Basin',
#  '/m/0sdr': 'Alfred of Beverly',
#  '/m/0sf2': 'Apr 22',
#  '/m/0sfl': '31st August',
#  '/m/0sg2': 'Ambrosius Autpertus',
#  '/m/0sgg': 'Abu Bakr al Siddiq',
#  '/m/0sgz': 'Ambrose of Camaldoli',
#  '/m/0shc': 'Ambrosians',
#  '/m/0shq': 'Ambrosiaster',
#  '/m/0sj2': 'Ambrosius Aurelius',
#  '/m/0sjj': 'Amun Ra',
#  '/m/0sk0': 'Ammon (nation)',
#  '/m/0skf': 'Ammonius Hermiae',
#  '/m/0sks': 'Sakkas',
#  '/m/0sl7': 'The Book of Ams',
#  '/m/0slq': 'Amphípolis',
#  '/m/0sm3': 'Imran (father of Mary)',
#  '/m/0smk': 'Amyntas i of macedon',
#  '/m/0smz': 'Amyntas III',
#  '/m/0snf': 'Anacharsis',
#  '/m/0snv': "'Ana",
#  '/m/0sp5': 'Ānanda',
#  '/m/0sq0': 'Ἀναξαγόρας',
#  '/m/0sqj': 'Anaxarch',
#  '/m/0sqy': 'Arnold Harris Mathew',
#  '/m/0ss2': 'Anaximenes of Lampsachus',
#  '/m/0sst': 'Anaxamenes of Miletus',
#  '/m/0st9': 'Ancus Martius',
#  '/m/0sts': 'The Andamans',
#  '/m/0sv7': 'Alexander anderson (mathematician)',
#  '/m/0svm': 'Andokidès',
#  '/m/0sw1': 'Andreani',
#  '/m/0swf': 'Andreas II of Hungary',
#  '/m/0sww': "Hume's Enquiry",
#  '/m/0sx6': 'Andrew of Longjumel',
#  '/m/0sxl': 'Andriscus of Macedon',
#  '/m/0sx_': 'Andronicus III Palaeologus',
#  '/m/0syg': 'Emperor Andronikos II',
#  '/m/0syz': 'Ανδρόνικος Α’ Κομνηνός',
#  '/m/0szg': 'Andronicus of cyrrhus',
#  '/m/0szt': 'Andronicus Rhodius',
#  '/m/0s_j': 'Marcellinus Ammianus',
#  '/m/0t0b': 'Houston, we have a problem',
#  '/m/0t0v': 'Apollo VII',
#  '/m/0t1b': 'Appollo 9',
#  '/m/0t1t': 'Undifferentiated arthritis',
#  '/m/0t29': 'Apr 02',
#  '/m/0t2t': 'Acetelyne',
#  '/m/0t3q': 'August 28th',
#  '/m/0t46': "'A'isha",
#  '/m/0t4p': 'Athenian non citizens',
#  '/m/0t53': 'Western Numerals',
#  '/m/0t5l': 'April 09',
#  '/m/0t6h': 'Lucius Apuleius of Madaura',
#  '/m/0t6_': 'Alexander Selcraig',
#  '/m/0t7d': 'Anti-ballistic missile defence',
#  '/m/0t7t': 'August 29th',
#  '/m/0t89': 'August 30, 2007',
#  '/m/0t8t': 'Imperial acre',
#  '/m/0t9s': 'ATP thermochemistry',
#  '/m/0tb8': 'Aegir',
#  '/m/0tbr': 'Oral anti-biotics',
#  '/m/0tc7': 'Ahnold',
#  '/m/0td4': 'Actium',
#  '/m/0tdx': 'Scamway',
#  '/m/0tfc': 'Vile maxim',
#  '/m/0tfw': 'Antoine-Laurent',
#  '/m/0tgc': 'Alan cox',
#  '/m/0tgv': 'Hermann Kolbe',
#  '/m/0th9': 'Apr 18',
#  '/m/0tht': '23 April',
#  '/m/0tj9': 'Bollywood/Actors/Male/Amitabh Bachchan',
#  '/m/0tjq': 'Allomorphic',
#  '/m/0tk4': 'Allophones',
#  '/m/0tkm': 'Affixion',
#  '/m/0tl2': 'Αγορευειν',
#  '/m/0tlk': 'ElementalAllotropes',
#  '/m/0tm1': 'Agathocles (disambiguation)',
#  '/m/0tmw': 'Augustin Louis, Baron Cauchy',
#  '/m/0tnc': 'Archemides',
#  '/m/0tnw': 'CAM (medicine)',
#  '/m/0tpc': 'Archimedean Solids',
#  '/m/0tpt': 'Antiprisms',
#  '/m/0tqz': 'Block approval voting',
#  '/m/0trv': 'Arizona state university',
#  '/m/0ts8': '14. of April',
#  '/m/0tss': 'Astoria, Oreg.',
#  '/m/0tt4': 'Alarums & Excursions',
#  '/m/0tth': 'Jarry, Alfred',
#  '/m/0tv9': 'Amaury of Jerusalem',
#  '/m/0tvs': 'Amaury of Lusignan',
#  '/m/0tw5': 'Anthemios of Tralles',
#  '/m/0twp': 'Absalon Hvide',
#  '/m/0tx2': 'Adhemar de Montell',
#  '/m/0txj': 'Alphonse of Toulouse',
#  '/m/0txz': 'Alfonso-Jordan',
#  '/m/0tyc': 'Ambrose the poet',
#  '/m/0tyq': 'Dark Deco',
#  '/m/0tz6': 'ASCII comic',
#  '/m/0t_2': 'American English/Standard American English',
#  '/m/0t_l': 'A.G. Spalding',
#  '/m/0t_y': 'Africa Alphabet',
#  '/m/0v0b': 'Aquire',
#  '/m/0v0s': 'Australian humour',
#  '/m/0v1h': 'AA11',
#  '/m/0v1x': 'American 77',
#  '/m/0v29': 'Ambuscade',
#  '/m/0v2s': 'Catalytic antibody',
#  '/m/0v34': 'Hawaiian radiation',
#  '/m/0v3l': 'Electrophoresis, agar gel',
#  '/m/0v3_': 'Multiple allelism',
#  '/m/0v4h': 'Pen a Oral',
#  '/m/0v5b': 'Super bug (bacteria)',
#  '/m/0v5r': 'Antigen nativity',
#  '/m/0v67': 'Autosomal',
#  '/m/0v74': 'Al-Qaedism',
#  '/m/0v7n': 'Alessandro Count Volta',
#  '/m/0v84': 'Argo Navis constellation',
#  '/m/0v8n': 'Andromeda (Greek mythology)',
#  '/m/0v94': 'Pump (constellation)',
#  '/m/0v9n': 'Ara constellation',
#  '/m/0vbk': 'Religion in Arkansas',
#  '/m/0vc1': 'Apus constellation',
#  '/m/0vck': 'Abadan',
#  '/m/0vd1': 'Al Fleming',
#  '/m/0vdk': 'Andrew carnagie',
#  '/m/0vf1': 'Approximants',
#  '/m/0vfh': 'Astronomer royal',
#  '/m/0vfx': 'Aeons',
#  '/m/0vg8': 'Scheduled air carriers',
#  '/m/0vgs': 'A history of the parliamentary Australian Democrats',
#  '/m/0vh3': 'Australian capital territory',
#  '/m/0vhm': 'Anamaniacs',
#  '/m/0vj1': 'Units of alcohol',
#  '/m/0vjr': 'Corretta Lipp',
#  '/m/0vk7': 'Andreas Cappellanus',
#  '/m/0vkm': 'Aclu',
#  '/m/0vl1': 'Tashlan',
#  '/m/0vlf': 'Adobe Systems Incorporated',
#  '/m/0vly': 'Alexander Principle',
#  '/m/0vmb': 'Alciatus',
#  '/m/0vmt': 'Arizona department of commerce',
#  '/m/0vn9': 'Apparent bightness',
#  '/m/0vnn': 'Absolute Visual Magnitude',
#  '/m/0vp4': 'Apollo-1',
#  '/m/0vpn': 'Apollo X',
#  '/m/0vq4': 'Apollo 12 Landing Site',
#  '/m/0vqn': 'Apollo XIV',
#  '/m/0vr4': 'Apollo XV',
#  '/m/0vrn': 'Apollo XVI',
#  '/m/0vs4': 'Apollo XVII',
#  '/m/0vsn': 'American revelution',
#  '/m/0vt4': 'Apr 17',
#  '/m/0vtn': 'Alan Ayckbourne',
#  '/m/0vv0': 'Building Engineering',
#  '/m/0vvc': 'Alpha Cenaturi',
#  '/m/0vvw': 'Amiga computer',
#  '/m/0vwc': 'Kara Shred',
#  '/m/0vx9': 'Actinophrys',
#  '/m/0vxn': 'Abel Janszoon Tasman',
#  '/m/0vy3': 'August 5th',
#  '/m/0vz3': 'Complex algebraic geometry',
#  '/m/0vzm': 'Austin City Connection',
#  '/m/0v_3': 'Moral argument',
#  '/m/0v_x': 'Aushwitz concentration camp',
#  '/m/0w0d': 'Toxopholite',
#  '/m/0w0x': 'Aalto, (Hugo) Alvar Henrik',
#  '/m/0w1r': 'Atomic Semantics',
#  '/m/0w22': 'Antarctic circumpolar current',
#  '/m/0w2h': 'Arbour Day',
#  '/m/0w2w': 'Freddie Ayer',
#  '/m/0w39': 'Andre Weil',
#  '/m/0w3s': 'Ekwesh',
#  '/m/0w45': 'Atle selberg',
#  '/m/0w4n': 'Æschylus',
#  '/m/0w54': 'Bernsteinstraße',
#  '/m/0w5k': 'Atlantic Baptist University',
#  '/m/0w5x': 'Andrew John Wiles',
#  '/m/0w6d': 'Anne Bronte',
#  '/m/0w6w': 'Works of Saint Augustine of Hippo',
#  '/m/0w7c': 'Acting technique',
#  '/m/0w7s': 'Aeronautical Engineering',
#  '/m/0w87': 'Athenian empire',
#  '/m/0w8r': 'August Horch',
#  '/m/0w94': 'Aviation electronics',
#  '/m/0w9n': 'Enyalos',
#  '/m/0wb4': 'Alexander grothendieck',
#  '/m/0wbn': 'Antidisestablishmentarians',
#  '/m/0wb_': 'Rule 62',
#  '/m/0wch': 'Alpha Blending',
#  '/m/0wcx': 'Ragged array',
#  '/m/0wdd': 'Australian anthem lyrics',
#  '/m/0wdx': 'Automatic number announcement circuit',
#  '/m/0wf7': 'Vespucci',
#  '/m/0wfr': 'Maillol',
#  '/m/0wg4': 'Canova',
#  '/m/0wgm': 'Rose Beuret',
#  '/m/0wh3': 'Ann Arbor, MI',
#  '/m/0whl': 'Succession Act of 1701',
#  '/m/0wj1': 'Skyjacker',
#  '/m/0wjj': 'Acropolis of athens',
#  '/m/0wjz': 'Adam weishaupt',
#  '/m/0wkf': 'Acorn Electron',
#  '/m/0wkt': 'A fire upon the deep',
#  '/m/0wl4': 'Aeronautical',
#  '/m/0wln': 'Louis Jean Lumière',
#  '/m/0wm4': 'Acts of Apostles',
#  '/m/0wmn': 'Assyrian Empire',
#  '/m/0wn4': 'Abiah',
#  '/m/0wnw': 'Dysphasia',
#  '/m/0wpc': 'Aortic diseases',
#  '/m/0wqz': 'Andrew Tridgell',
#  '/m/0wrd': 'AppleSoft BASIC',
#  '/m/0wrr': 'Soora Pappa',
#  '/m/0ws7': 'St. Louis Cardinals (NFL)',
#  '/m/0wsr': 'ATL Falcons',
#  '/m/0wt6': 'Theods',
#  '/m/0wtn': 'Subspace radio',
#  '/m/0wv1': 'Adalbert von Prag',
#  '/m/0wvh': 'Saint Aelfheah',
#  '/m/0wvv': 'Linear associative algebra',
#  '/m/0ww8': 'Axiom of Regularity',
#  '/m/0wwq': 'AIX',
#  '/m/0wx6': 'AppleTalk Address Resolution Protocol',
#  '/m/0wxp': 'Apple II',
#  '/m/0wy5': 'Apple ///',
#  '/m/0wyp': 'AVL-tree',
#  '/m/0wz5': 'Aliphatic Compounds',
#  '/m/0wzm': 'Terms or bounds (astrology)',
#  '/m/0w_3': 'Algebraic extension field',
#  '/m/0w_l': 'Ani D',
#  '/m/0x0d': "D'backs",
#  '/m/0x0w': 'Philosophy of art',
#  '/m/0x1c': 'The Ark of the Covenant',
#  '/m/0x1v': 'Angli',
#  '/m/0x29': 'ASTER CT-80',
#  '/m/0x2p': 'Boston Doves',
#  '/m/0x35': 'Atari STE',
#  '/m/0x3n': 'Aalyiah',
#  '/m/0x44': 'Armors',
#  '/m/0x4m': 'IED resistant vehicles',
#  '/m/0x4_': 'Anton Drexler',
#  '/m/0x5g': 'All Silent on the Western Front',
#  '/m/0x5x': 'Intellectual elitism',
#  '/m/0x67': 'African-americans',
#  '/m/0x6r': 'Angels in sikhism',
#  '/m/0x77': 'Allied Control Authority',
#  '/m/0x7m': 'Perl license',
#  '/m/0x82': 'Afrikans',
#  '/m/0x8l': 'Æolus',
#  '/m/0x9l': 'Alfred plea',
#  '/m/0xb8': 'Realism versus anti-realism',
#  '/m/0xbm': 'Arsenal fc',
#  '/m/0xc3': 'Cuisine of the united states',
#  '/m/0xcl': 'Ahmadshah Masood',
#  '/m/0xcy': 'Atlantas',
#  '/m/0xdf': 'Selfbiographical',
#  '/m/0xdy': 'Flavius Arcadius',
#  '/m/0xff': 'Arabic people',
#  '/m/0xfy': 'Cingulata',
#  '/m/0xh3': 'August 11th',
#  '/m/0xhm': 'Arcologies',
#  '/m/0xj2': '04-5',
#  '/m/0xjl': '20th April',
#  '/m/0xk2': 'April 19th',
#  '/m/0xkl': 'Amstrad CPC 472',
#  '/m/0xl0': 'Abdulaziz al Omari',
#  '/m/0xlc': 'St. Anselm of Canterbury',
#  '/m/0xlw': 'Aage Niels Bohr',
#  '/m/0xmb': 'Analytisk geometri',
#  '/m/0xn6': 'Arabic-based alphabet',
#  '/m/0xp0': 'Arctic Foxes',
#  '/m/0xpw': 'American folk beliefs',
#  '/m/0xqk': "Sid Meier's Alien Crossfire",
#  '/m/0xq_': 'The Maundy Thursday Rescue',
#  '/m/0xrg': 'ISO 639:hy',
#  '/m/0xrz': 'Additive synthesis',
#  '/m/0xsc': 'Fleet aircraft carriers',
#  '/m/0xsw': 'Sporozoa',
#  '/m/0xtb': 'Argentina cuisine',
#  '/m/0xtt': 'Apr 08',
#  '/m/0xv9': 'Attack the man',
#  '/m/0xvr': 'Uniform cost model',
#  '/m/0xw3': 'Aelle of Sussex',
#  '/m/0xwj': 'Atari Demos',
#  '/m/0xxc': 'Acadia University Axemen',
#  '/m/0xxq': 'Acoustic Guitars',
#  '/m/0xy6': 'John XXIII (antipope)',
#  '/m/0xyp': 'Analog science fiction and fact',
#  '/m/0xz3': 'Antionio Salieri',
#  '/m/0xzm': 'Civil activist',
#  '/m/0x_2': 'Atom clocks',
#  '/m/0x_l': 'Atlantic Avenue Tunnel',
#  '/m/0x_y': 'Grande Pre, Nova Scotia',
#  '/m/0y09': 'Pain pills',
#  '/m/0y0r': 'Amphib',
#  '/m/0y14': 'Stress resistant varieties',
#  '/m/0y1h': 'Object case',
#  '/m/0y2g': 'Roman Catholic succession',
#  '/m/0y3p': 'The first man Adam',
#  '/m/0y44': 'Hexuronic',
#  '/m/0y4n': 'Asymmetric digital subscriber line',
#  '/m/0y54': 'AFC Ajax Amsterdam',
#  '/m/0y5n': 'Sir Arthur Stanley Eddington',
#  '/m/0y63': 'Ant-eaters',
#  '/m/0y6l': '3 April',
#  '/m/0y7g': 'Personnel carrier',
#  '/m/0y7x': 'Assault guns',
#  '/m/0y8b': 'Tank killer',
#  '/m/0y8r': 'Light armored vehicle',
#  '/m/0y94': 'Self-propelled anti-aircraft',
#  '/m/0y9j': 'Alkmaar 54',
#  '/m/0yb0': 'Antonio Gaudi',
#  '/m/0ybj': 'Mammalian adrenal gland',
#  '/m/0yc0': 'American Media, Incorporated',
#  '/m/0ycc': 'Anthropomorphic personification',
#  '/m/0ycv': 'Christian Palestinian Aramaic',
#  '/m/0ydb': 'Titus (Bible)',
#  '/m/0yds': 'Americanisation',
#  '/m/0yf5': 'Actinide Element',
#  '/m/0yfp': 'Agnes Barley',
#  '/m/0yg5': 'Antonio Diabelli',
#  '/m/0ygn': 'Hill, Anita',
#  '/m/0yg_': 'Aug 10',
#  '/m/0yhh': 'Sound file format',
#  '/m/0yhw': 'Sound compression',
#  '/m/0yjq': 'Zone 51',
#  '/m/0yk6': 'Sound processing',
#  '/m/0ykl': 'Amdahls Law',
#  '/m/0yl2': 'Apr 27',
#  '/m/0yll': 'Ayahuasquero',
#  '/m/0ym0': 'Alfonso Leng',
#  '/m/0ymc': 'Abbe value',
#  '/m/0yn6': 'Ablative',
#  '/m/0ynq': 'Adamic tongue',
#  '/m/0yp1': 'Mahagonny',
#  '/m/0yph': 'Avery Jules Hopwood Novel Contest',
#  '/m/0ypv': 'Felix II',
#  '/m/0yq8': 'Alkaloids',
#  '/m/0yr4': 'Bishop of Canterbury',
#  '/m/0yrn': 'Albion, Mi',
#  '/m/0yr_': 'Holy Unction',
#  '/m/0ysg': 'Abstract Data Type',
#  '/m/0ysy': 'American Football League Championship',
#  '/m/0ytc': 'A.S. Rome',
#  '/m/0ytw': 'Immunoglobulin variable region',
#  '/m/0yvw': 'Anglo-Saxon Chronicles',
#  '/m/0ywc': 'Aston Martin Lagonda Limited',
#  '/m/0yww': 'Albert Pike',
#  '/m/0yx7': 'Alf Tales',
#  '/m/0yxl': 'Another Suburban Romance',
#  '/m/0yy2': 'Dostam',
#  '/m/0yyh': 'Andhara Pradesh',
#  '/m/0yy_': 'AGP slot',
#  '/m/0yzh': 'Aagesen, Andrew',
#  '/m/0yzw': 'Wasseralfingen',
#  '/m/0y_9': 'Alzheimer, Alois',
#  '/m/0y_t': 'Curule Aedile',
#  '/m/0z07': 'American Airlines Inc.',
#  '/m/0z0q': 'Antidepressive',
#  '/m/0z14': "Auger's Effect",
#  '/m/0z1j': 'Financial Asset',
#  '/m/0z1z': '盛田昭夫',
#  '/m/0z2f': 'Anodes',
#  '/m/0z2y': 'Vertical synchronization pulse',
#  '/m/0z39': 'Afrasia',
#  '/m/0z3t': 'April 11th',
#  '/m/0z49': 'Contact Cement',
#  '/m/0z4s': 'Hopkins, Sir Anthony',
#  '/m/0z58': 'Ardal OHanlon',
#  '/m/0z5n': 'Application-level interaction',
#  '/m/0z64': 'AMD Technologies',
#  '/m/0z6n': 'Albert Dürer',
#  '/m/0z74': 'Football (Australian rules)',
#  '/m/0z7n': 'AON Corporation',
#  '/m/0z7_': 'Alban berg',
#  '/m/0z8h': 'Analyse chemically',
#  '/m/0z8_': 'Agriculture Engineering',
#  '/m/0z9c': 'Recorded A Cappella Review Board',
#  '/m/0z9w': 'Arrange',
#  '/m/0zb8': 'Transport in Ascension Island',
#  '/m/0zbs': "Athanasius's Creed",
#  '/m/0zc6': 'Alicante/Alacant, Alicante',
#  '/m/0zcq': '4th August',
#  '/m/0zd6': 'Mac (Apple)',
#  '/m/0zdq': 'Anne Widdecombe',
#  '/m/0zf1': 'Aurungzebe',
#  '/m/0zfk': 'Alexandrines',
#  '/m/0zf_': 'Analogue computer',
#  '/m/0zgv': 'Moment of angle',
#  '/m/0zhb': 'Alberto Giacometti',
#  '/m/0zhv': 'Turn-offs',
#  '/m/0zj8': 'Anthems',
#  '/m/0zjp': 'Altdorfer, Albrecht',
#  '/m/0zk5': 'Ascanian House',
#  '/m/0zkm': 'Anthropods',
#  '/m/0zl3': 'Second temporal derivative of displacement',
#  '/m/0zlm': 'Art conservation and restoration',
#  '/m/0zm1': 'Anton Checkov',
#  '/m/0zmk': 'Action contre la Faim',
#  '/m/0znd': 'Apoptose',
#  '/m/0zp7': 'Having anal',
#  '/m/0zpr': 'Ålesund, Norway',
#  '/m/0zq6': 'Aarau, Switzerland',
#  '/m/0zqq': 'Canton of Aargau',
#  '/m/0zrn': 'Ababdeh',
#  '/m/0zs0': 'Quarter Horse (disambiguation)',
#  '/m/0zsg': 'Musa textilis',
#  '/m/0zsy': 'Abaddan',
#  '/m/0ztd': 'Abade',
#  '/m/0ztt': 'Abae',
#  '/m/0zv5': 'Khakassk',
#  '/m/0zv_': 'La Marseillaise (sculpture)',
#  '/m/0zwh': 'Apr 21',
#  '/m/0zxf': 'Amazon-stone',
#  '/m/0zxv': 'Ambrosius Bosschaert the Elder',
#  '/m/0zy7': 'Spiritual science',
#  '/m/0zyr': 'Aurocks',
#  '/m/0zz7': 'Atm nic',
#  '/m/0zzr': 'Perianal',
#  '/m/0z_n': 'Acantharians',
#  '/m/0_00': 'National Democratic Revolution',
#  '/m/0_0j': 'Amphet',
#  '/m/0_10': 'Асинхронна комуникация',
#  '/m/0_1c': 'Artelliry',
#  '/m/0_1w': 'Arnulf of Germany',
#  '/m/0_2c': 'Alexander Platz',
#  '/m/0_2v': 'AsDB',
#  '/m/0_38': 'Swān',
#  '/m/0_3s': 'Empress St. Adelaide',
#  '/m/0_4l': 'A.300',
#  ...}

# %% [markdown]
# # Train Freebase KG

# %%
import torch

print(f"GPU: {torch.cuda.is_available()}")
print(f"# of GPU: {torch.cuda.device_count()}")
# Out:
# GPU: True
# # of GPU: 1

# %%
from torch import cuda
from torch.optim import Adam

from torchkge.models import TransRModel
from torchkge.sampling import BernoulliNegativeSampler
from torchkge.utils import MarginLoss, DataLoader
from torchkge.utils.datasets import load_fb15k
from tqdm.autonotebook import tqdm

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# Load dataset
kg = load_fb15k('../raw_data')
kg_train, kg_valid, kg_test = kg.split_kg(share=0.8, validation=True)

# %%
def check_mid(mid):
    
    fb_mid = mid2ent
    kg_mid = kg_train.ent2ix
    
    if mid in fb_mid and mid in kg_mid:
        print(f'True: ({mid}):({mid2ent[mid]}) is valid for both freebase and knowledge graph')
    elif mid in fb_mid and mid not in kg_mid:
        print(f'False: ({mid}):({mid2ent[mid]}) is not valid for knowledge graph')
    elif (mid not in fb_mid) and (mid in kg_mid):
        print(f'False: {mid} is not valid for freebase')
    else:
        print(f'False: {mid} is not valid for both freebase and knowledge graph')

# %%
target_mid = ['/m/011v3', 
              '/m/03x6m',
              '/m/06l22',
              '/m/0hvgt',
              '/m/045xx',
              '/m/023fb', 
              '/m/050fh' ,
              '/m/01634x' ,
              '/m/0xbm',
              '/m/0hvjr', 
              '/m/04ltf', 
              '/m/01w_d6', 
              '/m/0175rc', 
              '/m/01_1kk', 
              '/m/03w7kx', 
              '/m/019lxm', 
              '/m/023zd7', 
              '/m/02bh_v', 
              '/m/06qjgc',
              '/m/0y54',
              '/m/0kqbh',
              '/m/0jgd',
              '/m/02y9kd',
            ]

# %%
for t in target_mid:
    check_mid(t)
# Out:
# True: (/m/011v3):(Milan A.C.) is valid for both freebase and knowledge graph
# True: (/m/03x6m):(Internazionale) is valid for both freebase and knowledge graph
# True: (/m/06l22):(Royal Madrid) is valid for both freebase and knowledge graph
# True: (/m/0hvgt):(CF Barcelona) is valid for both freebase and knowledge graph
# True: (/m/045xx):(Juventus fc) is valid for both freebase and knowledge graph
# True: (/m/023fb):(Chelsea F.C. season 2011-12) is valid for both freebase and knowledge graph
# True: (/m/050fh):(Man UTD) is valid for both freebase and knowledge graph
# True: (/m/01634x):(Man c) is valid for both freebase and knowledge graph
# True: (/m/0xbm):(Arsenal fc) is valid for both freebase and knowledge graph
# True: (/m/0hvjr):(Tottenham Hotspur Foundation) is valid for both freebase and knowledge graph
# True: (/m/04ltf):(Liverpool football club) is valid for both freebase and knowledge graph
# True: (/m/01w_d6):(BV Borussia Dortmund) is valid for both freebase and knowledge graph
# True: (/m/0175rc):(Fc Bayern) is valid for both freebase and knowledge graph
# True: (/m/01_1kk):(Paris St Germaine) is valid for both freebase and knowledge graph
# True: (/m/03w7kx):(Football Club de Lyon) is valid for both freebase and knowledge graph
# True: (/m/019lxm):(Santos (football club)) is valid for both freebase and knowledge graph
# True: (/m/023zd7):(Club Atlético Boca Juniors) is valid for both freebase and knowledge graph
# True: (/m/02bh_v):(Argentinian national football team) is valid for both freebase and knowledge graph
# True: (/m/06qjgc):(Lionel Andres Messi) is valid for both freebase and knowledge graph
# True: (/m/0y54):(AFC Ajax Amsterdam) is valid for both freebase and knowledge graph
# True: (/m/0kqbh):(PSV (football club)) is valid for both freebase and knowledge graph
# True: (/m/0jgd):(Arxentina) is valid for both freebase and knowledge graph
# False: (/m/02y9kd):(Jisung Park) is not valid for knowledge graph

# %%
target_ix = [kg_train.ent2ix[m] for m in target_mid[:-1]]

# %%
def training(ent_emb_dim=10, rel_emb_dim=10, lr=0.0004, n_epochs=100, b_size=32768, margin=0.5):
    
    # Define the model and criterion
    model = TransRModel(ent_emb_dim, rel_emb_dim, kg_train.n_ent, kg_train.n_rel)
    criterion = MarginLoss(margin)
    
    # Move everything to CUDA if available
    if cuda.is_available():
        cuda.empty_cache()
        model.cuda()
        criterion.cuda()
        
    # Define the torch optimizer to be used
    optimizer = Adam(model.parameters(), lr=lr, weight_decay=1e-5)
    
    # KG training options
    sampler = BernoulliNegativeSampler(kg_train)
    dataloader = DataLoader(kg_train, batch_size=b_size, use_cuda='all')
    
    # Training
    iterator = tqdm(range(n_epochs), unit='epoch')
    for epoch in iterator:
        running_loss = 0.0
        for i, batch in enumerate(dataloader):
            h, t, r = batch[0], batch[1], batch[2]
            n_h, n_t = sampler.corrupt_batch(h, t, r)

            optimizer.zero_grad()

            # forward + backward + optimize
            pos, neg = model(h, t, n_h, n_t, r)
            loss = criterion(pos, neg)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
        iterator.set_description(
            'Epoch {} | mean loss: {:.5f}'.format(epoch + 1, running_loss / len(dataloader)))
    model.normalize_parameters()
    
    return model

# %% [markdown]
# ## Epcoh : 10

# %%
# training

train_config = {'ent_emb_dim': 10, 
                'rel_emb_dim': 10, 
                'lr': 0.0004,
                'n_epochs': 10,
                'b_size': 32768,
                'margin': 0.5}

model = training(**train_config)
ent, _, _ = model.get_embeddings()
# Out:
#   0%|          | 0/10 [00:00<?, ?epoch/s]

# %%
# dimension reduction for visualization

ent_embedded = TSNE(n_components=2).fit_transform(ent.cpu())
x = ent_embedded[:,0]
y = ent_embedded[:,1]
valid_mid = [kg_train.ix2ent[i] for i in range(kg_train.n_ent)]
annotate = [mid2ent[m] if m in mid2ent else None for m in valid_mid]

# %%
# visualization

from os import makedirs
from os.path import exists

result_path = '../experiment/visualization/freebase/football'
save_fig = True

if not exists(result_path):
    makedirs(result_path, exist_ok=True)
    
plt.figure(figsize=(20,20))
for idx in target_ix:  
    plt.text(x[idx],y[idx],annotate[idx],color='red', weight="bold")
    plt.title('TransR - Epoch10')
plt.scatter(x,y, alpha=0.1);
if save_fig:
    plt.savefig(result_path + f'/transr_epoch{10}_size{20}.png', dpi='figure')

# %% [markdown]
# ## Epoch: 300

# %%
# training

train_config = {'ent_emb_dim': 10, 
                'rel_emb_dim': 10, 
                'lr': 0.0004,
                'n_epochs': 300,
                'b_size': 32768,
                'margin': 0.5}

model = training(**train_config)
ent, _, _ = model.get_embeddings()
# Out:
#   0%|          | 0/300 [00:00<?, ?epoch/s]

# %%
# dimension reduction for visualization

ent_embedded = TSNE(n_components=2).fit_transform(ent.cpu())
x = ent_embedded[:,0]
y = ent_embedded[:,1]
valid_mid = [kg_train.ix2ent[i] for i in range(kg_train.n_ent)]
annotate = [mid2ent[m] if m in mid2ent else None for m in valid_mid]

# %%
# visualization

from os import makedirs
from os.path import exists

result_path = '../experiment/visualization/freebase/football'
save_fig = True

if not exists(result_path):
    makedirs(result_path, exist_ok=True)
    
plt.figure(figsize=(20,20))
for idx in target_ix:  
    plt.text(x[idx],y[idx],annotate[idx],color='red', weight="bold")
    plt.title('TransR - Epoch300')
plt.scatter(x,y, alpha=0.1);
if save_fig:
    plt.savefig(result_path + f'/transr_epoch{300}_size{20}.png', dpi='figure')

# %% [markdown]
# ## Epoch: 1000

# %%
# training

train_config = {'ent_emb_dim': 10, 
                'rel_emb_dim': 10, 
                'lr': 0.0004,
                'n_epochs': 1000,
                'b_size': 32768,
                'margin': 0.5}

model = training(**train_config)
ent, _, _ = model.get_embeddings()
# Out:
#   0%|          | 0/1000 [00:00<?, ?epoch/s]

# %%
# dimension reduction for visualization

ent_embedded = TSNE(n_components=2).fit_transform(ent.cpu())
x = ent_embedded[:,0]
y = ent_embedded[:,1]
valid_mid = [kg_train.ix2ent[i] for i in range(kg_train.n_ent)]
annotate = [mid2ent[m] if m in mid2ent else None for m in valid_mid]

# %%
# visualization

from os import makedirs
from os.path import exists

result_path = '../experiment/visualization/freebase/football'
save_fig = True

if not exists(result_path):
    makedirs(result_path, exist_ok=True)
    
plt.figure(figsize=(20,20))
for idx in target_ix:  
    plt.text(x[idx],y[idx],annotate[idx],color='red', weight="bold")
    plt.title('TransR - Epoch1000')
plt.scatter(x,y, alpha=0.1);
if save_fig:
    plt.savefig(result_path + f'/transr_epoch{1000}_size{20}.png', dpi='figure')

# %%
plt.figure(figsize=(100,100))
for idx in target_ix:  
    plt.text(x[idx],y[idx],annotate[idx],color='red', weight="bold")
    plt.title('TransR - Epoch1000')
plt.scatter(x,y, alpha=0.1);
if save_fig:
    plt.savefig(result_path + f'/transr_epoch{1000}_size{100}.png', dpi='figure')
